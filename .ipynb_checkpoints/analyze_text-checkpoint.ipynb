# %%
import pandas as pd
import gensim
import nltk
import re
import string

# %%
ds_df = pd.read_csv("data\Biologist_text_data.csv")

# %%
ds_df.head()
# Out:
#    Unnamed: 0                                    job_description  \
# 0           0  Assay biologist needed to revolutionize cancer...
# 1           2  $46,987 a yearThis position will perform a wid...
# 2           3  Job Field: REDE - Research & Development\r\nLo...
# 3           4  $26,000 - $32,500 a yearPart-time, ContractSum...
# 4           5  $50,000 - $80,000 a yearEnvironmental consulti...
#
#                 job_location  \
# 0                 Durham, NC
# 1  West Palm Beach, FL 33406
# 2        Tarrytown, NY 10591
# 3                   Reno, NV
# 4            Asbury Park, NJ
#
#                                            job_title  sponsored
# 0  Assay biologist to revolutionize cancer diagnosis       True
# 1                         Invasive Species Biologist       True
# 2              Biologist II (Microbial Fermentation)       True
# 3    Aquarium Marine Freshwater Technician Biologist      False
# 4                                Ecologist/Biologist      False

# %%
# Create initial documents list

doc = list(ds_df.job_description)

# Remove punctuation, then tokenize documents
punc = re.compile( '[%s]' % re.escape( string.punctuation ) )

clean_vec = [ ]

for d in doc:
    d = d.lower()
    d = punc.sub('', d )
    clean_vec.append(d)
    
ds_df['clean_description'] = clean_vec

# %%
ds_df.to_csv("biologist_text.csv", index=False)

# %%
ds_df.clean_description.head()
# Out:
# 0    assay biologist needed to revolutionize cancer...
# 1    46987 a yearthis position will perform a wide ...
# 2    job field rede  research  development\r\nlocat...
# 3    26000  32500 a yearparttime contractsummary of...
# 4    50000  80000 a yearenvironmental consulting fi...
# Name: clean_description, dtype: object

# %%
salary_pattern = re.compile("^([0-9]+)[ ]*([0-9]*)")

salary = list()

for description in ds_df['clean_description']:
    match_obj = salary_pattern.match(description)
    
    if match_obj is None:
        salary.append(None)
        
    else:
        
        salary_low = match_obj.group(1)
        salary_high = match_obj.group(2)
        
        if salary_high:
            salary.append((int(salary_low) + int(salary_high))//2)
        else:
            salary.append(int(salary_low))
        
ds_df['salary'] = salary

# %%
ds_df.loc[:,['clean_description', 'salary']].head(100)
# Out:
#                                     clean_description    salary
# 0   assay biologist needed to revolutionize cancer...       NaN
# 1   46987 a yearthis position will perform a wide ...   46987.0
# 2   job field rede  research  development\r\nlocat...       NaN
# 3   26000  32500 a yearparttime contractsummary of...   29250.0
# 4   50000  80000 a yearenvironmental consulting fi...   65000.0
# 5   cardno is seeking a bat biologist to work with...       NaN
# 6   39611  63378 a yeartemporarync wildlife resour...   51494.0
# 7   40939  56352 a yearinternshipthe connecticut d...   48645.0
# 8   entry level biologist needed\r\npiper companie...       NaN
# 9   46550  56597 a yearparttimeplease note the dep...   51573.0
# 10  20  30 an hourparttimetranscon environmental i...      25.0
# 11  this position will support our fast paced clie...       NaN
# 12  22  28 an hourestablished in 1999 transcon env...      25.0
# 13  biologist  cellbased assayposition overviewadv...       NaN
# 14  the laboratory of genetically encoded small mo...       NaN
# 15  soteria biotherapeutics is seeking a biologist...       NaN
# 16  wra inc is an environmental consulting firm ba...       NaN
# 17  the northwest region is looking for a biologis...       NaN
# 18  please read entirely before applyingflorida ag...       NaN
# 19  40000 a yearresponsibilities will include but ...   40000.0
# 20  company summarys2s erm is a familyowned and op...       NaN
# 21  36677  58683 a yearsalary grade gn09  recruitm...   47680.0
# 22  performs independent forensic testing of biolo...       NaN
# 23  locations babraham research campus cambridge u...       NaN
# 24  81548  126062 a yearparttimeduties\r\nsummary\...  103805.0
# 25  56233  88450 a yearparttimeduties\r\nsummary\r...   72341.0
# 26  20  40 an hourparttimejoin cellomics technolog...      30.0
# 27  job description\r\nvertex pharmaceuticals inco...       NaN
# 28  45000  60000 a yearwe are currently looking fo...   52500.0
# 29  how would you like to be on the front lines of...       NaN
# ..                                                ...       ...
# 70  61218  79586 a yearparttimearea of considerati...   70402.0
# 71  66577  86553 a yearparttimethis position is pa...   76565.0
# 72  3684  4832 a monthdescription\r\n\r\n\r\nthe d...    4258.0
# 73  design create and screen phage libraries and v...       NaN
# 74  eurofins lancaster laboratories pss is searchi...       NaN
# 75  internshipjob description computational biolog...       NaN
# 76  biologist 1  151025\r\ndescription\r\n\r\nabou...       NaN
# 77  2029  2639 an hourfor more information about t...    2334.0
# 78  50900  67800 a yearairport wildlife biologist\...   59350.0
# 79  18  20 an hourcontractadvance services is seek...      19.0
# 80  job details\r\ndescription\r\ntrinity river au...       NaN
# 81  seeking a highly motivated research associate ...       NaN
# 82  \r\nour story\r\n\r\n\r\nwe started medmen wit...       NaN
# 83  18  20 an hourtemporary contractadvance servic...      19.0
# 84  contractgrb environmental services inc is purs...       NaN
# 85  cardno is seeking a staff or senior staff scie...       NaN
# 86  return applicationresume to\r\n\r\nbell labora...       NaN
# 87  the university of chicagos department of ecolo...       NaN
# 88  job description\r\nthis role will be responsib...       NaN
# 89  5718  7662 a monththis posting may close at an...    6690.0
# 90  53877  60345 a yeargeneral statement of duties...   57111.0
# 91  90000  100000 a yearyeast molecular biologistc...   95000.0
# 92  at memorial sloan kettering msk we’re not only...       NaN
# 93  28  30 an hourestablished in 1999 transcon env...      29.0
# 94  descriptionblanton  associates inc seeks a wil...       NaN
# 95  10x genomics  httpwww10xgenomicscom  is buildi...      10.0
# 96  3980  6252 a monthparttime temporaryfinal fili...    5116.0
# 97  verge genomics is seeking a computational biol...       NaN
# 98  bbi is currently looking for qualified biologi...       NaN
# 99  position title biologistphysiologist phd\r\n\r...       NaN
#
# [100 rows x 2 columns]

# %%
# %matplotlib inline

# %%
ds_df.salary.plot(kind='hist', bins=50)

# %%
ds_df.loc[ds_df['salary'] < 30000, 'salary'] = None

# %%
two_state = re.compile("^[A-Za-z]+, ([A-Za-z]{2})")
long_state = re.compile("^[A-Za-z]+, ([A-Za-z]{3-10})")

# %%
for location in ds_df['job_location']:
    state_match = two_state.match(location)
    if state_match:
        print(state_match.group(1))

# %%
stop_words = nltk.corpus.stopwords.words( 'english' )

for i in range( 0, len( term_vec ) ):
    term_list = [ ]

    for term in term_vec[ i ]:
        if term not in stop_words:
            term_list.append( term )

    term_vec[ i ] = term_list

# %%
# Stem terms
# Porter stem remaining terms

porter = nltk.stem.porter.PorterStemmer()

for i in range( 0, len( term_vec ) ):
    for j in range( 0, len( term_vec[ i ] ) ):
        term_vec[ i ][ j ] = porter.stem( term_vec[ i ][ j ] )

# %%
#  Convert term vectors into gensim dictionary

dict = gensim.corpora.Dictionary( term_vec )

corp = [ ]
for i in range( 0, len( term_vec ) ):
    corp.append( dict.doc2bow( term_vec[ i ] ) )

#  Create TFIDF vectors based on term vectors bag-of-word corpora

tfidf_model = gensim.models.TfidfModel( corp )

tfidf = [ ]
for i in range( 0, len( corp ) ):
    tfidf.append( tfidf_model[ corp[ i ] ] )

#  Create pairwise document similarity index

n = len( dict )
index = gensim.similarities.SparseMatrixSimilarity( tfidf_model[ corp ], num_features = n )

#  Print TFIDF vectors and pairwise similarity per document

for i in range( 0, len( tfidf ) ):
    s = 'Doc ' + str( i + 1 ) + ' TFIDF:'

    for j in range( 0, len( tfidf[ i ] ) ):
        s = s + ' (' + dict.get( tfidf[ i ][ j ][ 0 ] ) + ','
        s = s + ( '%.3f' % tfidf[ i ][ j ][ 1 ] ) + ')'


for i in range( 0, len( corp ) ):
    sim = index[ tfidf_model[ corp[ i ] ] ]

# %%
important_words = []

for i in range( 0, len( tfidf ) ):
    s = 'Doc ' + str( i + 1 ) + ' TFIDF:'

    for j in range( 0, len( tfidf[ i ] ) ):
        s = s + ' (' + dict.get( tfidf[ i ][ j ][ 0 ] ) + ','
        s = s + ( '%.3f' % tfidf[ i ][ j ][ 1 ] ) + ')'

    print s
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-d8bde7b431de> in <module>()
# ----> 1 corp.shape
#
# AttributeError: 'list' object has no attribute 'shape'

# %%
ds_df.
