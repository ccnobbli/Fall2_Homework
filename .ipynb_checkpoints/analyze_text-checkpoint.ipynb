# %%
import pandas as pd
import gensim
import nltk
import re
import string

# %%
# %matplotlib inline

# %%
ds_df = pd.read_csv("data/indeed/Data_Engineer_text_data.csv")

# %%
ds_df.head()
# Out:
#    Unnamed: 0                                    job_description  \
# 0           0  ContractSr AWS Data EngineerRemote project3 mo...
# 1           2  At ISM Connect, we believe that success is ach...
# 2           3  Data EngineerDoers Wanted. Dreamers Encouraged...
# 3           4  Product Delivery EngineerClearsense is buildin...
# 4           5  In this role, the candidate will be responsibl...
#
#        job_location                 job_title  sponsored
# 0  Maui Meadows, HI         AWS Data engineer       True
# 1    Doylestown, PA             Data Engineer       True
# 2    Scottsdale, AZ             Data Engineer       True
# 3  Jacksonville, FL  Healthcare Data Engineer       True
# 4      New York, NY             Data Engineer       True

# %%
# Clean up punctuation and make it lower case

doc = list(ds_df.job_description)

punc = re.compile( '[%s]' % re.escape( string.punctuation ) )

clean_vec = [ ]

for d in doc:
    d = d.lower()
    d = punc.sub('', d )
    clean_vec.append(d)
    
ds_df['clean_description'] = clean_vec

# %%
ds_df.clean_description.head()
# Out:
# 0    contractsr aws data engineerremote project3 mo...
# 1    at ism connect we believe that success is achi...
# 2    data engineerdoers wanted dreamers encouragedo...
# 3    product delivery engineerclearsense is buildin...
# 4    in this role the candidate will be responsible...
# Name: clean_description, dtype: object

# %%
salary_pattern = re.compile("^([0-9]+)[ ]*([0-9]*)")

salary = list()

for description in ds_df['clean_description']:
    match_obj = salary_pattern.match(description)
    
    if match_obj is None:
        salary.append(None)
        
    else:
        
        salary_low = match_obj.group(1)
        salary_high = match_obj.group(2)
        
        if salary_high:
            salary.append((int(salary_low) + int(salary_high))//2)
        else:
            salary.append(int(salary_low))
        
ds_df['salary'] = salary

# %%
ds_df.loc[:,['clean_description', 'salary']].head(20)
# Out:
#                                     clean_description   salary
# 0   contractsr aws data engineerremote project3 mo...      NaN
# 1   at ism connect we believe that success is achi...      NaN
# 2   data engineerdoers wanted dreamers encouragedo...      NaN
# 3   product delivery engineerclearsense is buildin...      NaN
# 4   in this role the candidate will be responsible...      NaN
# 5   data engineer  developerlooking to be part of ...      NaN
# 6   job summarywe are hiring a senior data enginee...      NaN
# 7   internshipposition summary\r\nthe new york cou...      NaN
# 8   to be based in the south west we are looking f...      NaN
# 9   50000 a yearjob description\r\n\r\nno computer...  50000.0
# 10  book of the month is looking for a detailorien...      NaN
# 11  you will have the opportunity to work as part ...      NaN
# 12  job description\r\nwe are a startup within one...      NaN
# 13  job description\r\nthinking big\r\ndo you want...      NaN
# 14  description\r\nthe new york yankees baseball o...      NaN
# 15  contractno optsgcusc preferablelong term contr...      NaN
# 16  30000  37500 a yearthis is an apprenticeship o...  33750.0
# 17  atni is looking for an experienced lanwan data...      NaN
# 18  to analyze data and informational requirements...      NaN
# 19  job field rede  research  development\r\nlocat...      NaN

# %%
ds_df.salary.plot(kind='hist', bins=50)

# %%
ds_df.loc[ds_df['salary'] < 30000, 'salary'] = None

# %%
two_state = re.compile("^[A-Za-z \.-]+, ([A-Za-z]{2})")
long_state = re.compile("^[A-Za-z]+, ([A-Za-z]{3-10})")

# %%
states = []
for location in ds_df['job_location']:
    state_match = two_state.match(location)
    if state_match:
        states.append(state_match.group(1))
    else:
        states.append(None)
        
ds_df['state'] = states

# %%
ds_df.loc[:, ['job_location', 'state']].head(20)
ds_df[ds_df.state.isna()]
# Out:
#      Unnamed: 0                                    job_description  \
# 8             9  To be based in the South West we are looking f...
# 22           25  Data Engineer – Claims Data Science\r\nDescrip...
# 64           71  Part-timeWho are we?\r\n\r\nSince 2011, Genera...
# 80           88  About Kraken\r\n\r\nKraken is one of the large...
# 93          102  Auth0, a global leader in Identity-as-a-Servic...
# 146         160  At Toptal, we measure everything and always re...
# 149         163  This position will require re-location to clie...
# 156         170  SemanticBits is looking for a Data Engineer/Wr...
# 268         285  Short Description\r\n\r\nAbout Capgemini\r\nA ...
# 340         365  Summary:\r\nThe Data Engineer is responsible f...
# 348         377  VividCortex is a groundbreaking database monit...
# 352         382  ContractSenior Data Engineer (Remote)\r\nApply...
# 371         401  Job Description\r\nWe are looking for candidat...
# 418         452  -----------------------------\r\nSenior Data E...
# 491         526  The Schoolzilla Mission: Empower People to Use...
# 513         550  Big Data Engineer\r\n\r\nAs a (Big Data) Softw...
# 599         639  If you have experience with big data solutions...
# 632         673  As a Data Engineer at Simon-Kucher, you will b...
# 649         690  About Capgemini\r\n\r\nWith almost 200,000 peo...
# 694         736  Requisition ID: 25606\r\n\r\nThere are current...
# 701         743  Data Engineer - Downtown Boston - $65-90K\r\n\...
# 832         876  Overview of the Role:\r\nThe Staff Data Engine...
# 873         918  Sr. Data Engineer/Architect\r\n\r\nAbout Capge...
#
#        job_location                                   job_title  sponsored  \
# 8     United States                               Data Engineer      False
# 22    United States                               Data Engineer      False
# 64   North Carolina                               Data Engineer      False
# 80           Remote                               Data Engineer      False
# 93           Remote                               Data Engineer      False
# 146   United States                               Data Engineer      False
# 149   United States                   BIG DATA ENGINEER/TRAINEE      False
# 156          Remote                               Data Engineer      False
# 268        Illinois                           Big Data Engineer      False
# 340         Alabama                               Data Engineer      False
# 348   United States                               Data Engineer      False
# 352   Massachusetts                  Sr. Data Engineer (REMOTE)      False
# 371   United States  Business Intelligence Engineer, Field FP&A      False
# 418      California               Senior Data Engineer (REMOTE)      False
# 491   United States                          Lead Data Engineer      False
# 513   United States                        Big Data Engineer II      False
# 599   United States                           Big Data Engineer      False
# 632          Oregon               Data Engineer (m/f) – Germany      False
# 649  North Carolina                               Data Engineer      False
# 694   Massachusetts                               Data Engineer      False
# 701   United States                               Data Engineer      False
# 832          Remote                         Staff Data Engineer      False
# 873  North Carolina                 Sr. Data Engineer/Architect      False
#
#                                      clean_description  salary state
# 8    to be based in the south west we are looking f...     NaN  None
# 22   data engineer – claims data science\r\ndescrip...     NaN  None
# 64   parttimewho are we\r\n\r\nsince 2011 general a...     NaN  None
# 80   about kraken\r\n\r\nkraken is one of the large...     NaN  None
# 93   auth0 a global leader in identityasaservice id...     NaN  None
# 146  at toptal we measure everything and always rel...     NaN  None
# 149  this position will require relocation to clien...     NaN  None
# 156  semanticbits is looking for a data engineerwra...     NaN  None
# 268  short description\r\n\r\nabout capgemini\r\na ...     NaN  None
# 340  summary\r\nthe data engineer is responsible fo...     NaN  None
# 348  vividcortex is a groundbreaking database monit...     NaN  None
# 352  contractsenior data engineer remote\r\napply d...     NaN  None
# 371  job description\r\nwe are looking for candidat...     NaN  None
# 418  \r\nsenior data engineer remote\r\n\r\n\r\nabo...     NaN  None
# 491  the schoolzilla mission empower people to use ...     NaN  None
# 513  big data engineer\r\n\r\nas a big data softwar...     NaN  None
# 599  if you have experience with big data solutions...     NaN  None
# 632  as a data engineer at simonkucher you will be ...     NaN  None
# 649  about capgemini\r\n\r\nwith almost 200000 peop...     NaN  None
# 694  requisition id 25606\r\n\r\nthere are currentl...     NaN  None
# 701  data engineer  downtown boston  6590k\r\n\r\na...     NaN  None
# 832  overview of the role\r\nthe staff data enginee...     NaN  None
# 873  sr data engineerarchitect\r\n\r\nabout capgemi...     NaN  None

# %%
job = 'bioinformatics'
df = pd.read_csv("data/indeed/" + job + "_clean.csv")
df['search_term'] = job

# %%
df.head()
# Out:
#                                          job_title  \
# 0  Entry Level Information Specialist/Non-Clinical
# 1                          BIOINFORMATICS ENGINEER
# 2                Bioinformatics Research Scientist
# 3                         Bioinformatics Scientist
# 4                       Bioinformatics Internships
#
#                                    clean_description   salary state  \
# 0  38000  40000 a yearjob summary descriptionif y...  39000.0    NJ
# 1  twinstrand biosciences a seattlebased genomics...      NaN    WA
# 2  bioinformatics research scientistthe candidate...      NaN    PA
# 3  want to be part of a company whose goal is to ...      NaN    NJ
# 4  paid bioinformatics annotator internships are ...      NaN    VA
#
#    sponsored     search_term
# 0       True  bioinformatics
# 1       True  bioinformatics
# 2       True  bioinformatics
# 3       True  bioinformatics
# 4      False  bioinformatics

# %%
def _removeNonAscii(s): return "".join(i for i in s if ord(i)<128)

def _removeReturn(col):
    return [re.sub(r"\r", "", item) for item in col]

# %%
job = 'data_scientist'
df = pd.read_csv("data/indeed/" + job + "_clean.csv")
#df['search_term'] = job
#df = df.loc[:,['job_title', 'clean_description', 'salary', 'state', 'sponsored', 'search_term' ]]

df['job_title'] = [_removeNonAscii(title) for title in df.job_title ]
df['clean_description'] = [_removeNonAscii(title) for title in df.clean_description ]

#df.to_csv("data/indeed/" + job + "_clean.csv", index=False, encoding='latin1')

# %%
df.clean_description[0]
# Out:
# 'given substantial growth and impact at crowe the machine learning team has formed into an official unit advanced data science ads which is responsible for all machine learning and artificial intelligence throughout the firm this team works on a wide variety of projects utilizing numerous areas of machine learning including supervised regressionclassification unsupervised learning anomaly detection nlp reinforcement learning deep learning forecasting etc\r\r\r\r\n\r\r\r\r\nleverage large sets of structured and unstructured data to develop tactical and strategic insights collaborate with analytic and data teams to set objectives approaches and work plans research and evaluate new analytical methodologies approaches and solutions develop and validate statistical forecasting models and tools interpret and communicate analytic results to analytical and nonanalytical business partners and executive decision makers'

# %%
print(ds_df.state.describe())

len(ds_df)
# Out:
# count     938
# unique     43
# top        CA
# freq      276
# Name: state, dtype: object
# 961

# %%
stop_words = nltk.corpus.stopwords.words( 'english' )

for i in range( 0, len( term_vec ) ):
    term_list = [ ]

    for term in term_vec[ i ]:
        if term not in stop_words:
            term_list.append( term )

    term_vec[ i ] = term_list

# %%
# Stem terms
# Porter stem remaining terms

porter = nltk.stem.porter.PorterStemmer()

for i in range( 0, len( term_vec ) ):
    for j in range( 0, len( term_vec[ i ] ) ):
        term_vec[ i ][ j ] = porter.stem( term_vec[ i ][ j ] )

# %%
#  Convert term vectors into gensim dictionary

dict = gensim.corpora.Dictionary( term_vec )

corp = [ ]
for i in range( 0, len( term_vec ) ):
    corp.append( dict.doc2bow( term_vec[ i ] ) )

#  Create TFIDF vectors based on term vectors bag-of-word corpora

tfidf_model = gensim.models.TfidfModel( corp )

tfidf = [ ]
for i in range( 0, len( corp ) ):
    tfidf.append( tfidf_model[ corp[ i ] ] )

#  Create pairwise document similarity index

n = len( dict )
index = gensim.similarities.SparseMatrixSimilarity( tfidf_model[ corp ], num_features = n )

#  Print TFIDF vectors and pairwise similarity per document

for i in range( 0, len( tfidf ) ):
    s = 'Doc ' + str( i + 1 ) + ' TFIDF:'

    for j in range( 0, len( tfidf[ i ] ) ):
        s = s + ' (' + dict.get( tfidf[ i ][ j ][ 0 ] ) + ','
        s = s + ( '%.3f' % tfidf[ i ][ j ][ 1 ] ) + ')'


for i in range( 0, len( corp ) ):
    sim = index[ tfidf_model[ corp[ i ] ] ]

# %%
important_words = []

for i in range( 0, len( tfidf ) ):
    s = 'Doc ' + str( i + 1 ) + ' TFIDF:'

    for j in range( 0, len( tfidf[ i ] ) ):
        s = s + ' (' + dict.get( tfidf[ i ][ j ][ 0 ] ) + ','
        s = s + ( '%.3f' % tfidf[ i ][ j ][ 1 ] ) + ')'

    print s
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-d8bde7b431de> in <module>()
# ----> 1 corp.shape
#
# AttributeError: 'list' object has no attribute 'shape'

# %%
ds_df.
